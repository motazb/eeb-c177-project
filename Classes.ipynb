# %%
from urllib.request import urlopen

hist = urlopen("https://sa.ucla.edu/ro/Public/SOC/Results/ClassDetail?term_cd=20S&subj_area_cd=HIST%20%20%20&crs_catlg_no=0010B%20%20%20&class_id=221065200&class_no=%20001%20%20").read()
randm = urlopen("https://sa.ucla.edu/ro/Public/SOC/Results/ClassDetail?term_cd=20S&subj_area_cd=AF%20AMER&crs_catlg_no=0019%20%20%20%20&class_id=413057202&class_no=%20002%20%20").read()

#Imports that webpage with class availability

# %%
import re
import threading

def check(classes):
    threading.Timer(2.0, check, (classes,)).start()
    string = re.sub("[^a-zA-z]", " ", str(classes))
    if 'Open' in string:
        print('Open!')
    if 'Open' not in string:
        print('Closed')
check(hist)
# Out:
# Closed
# classes is Closed!
# classes is Closed!
# classes is Closed!
# Closed
# Closed
# Closed

# %%
import re
import time
import threading

#def check(classes):
#starttime=time.time()
threading.Timer(2.0, check).start()
string = re.sub("[^a-zA-z]", " ", str(randm))
if 'Open' in string:
    print('Open!')
    #if 'Open' not in string:
        #print('Closed!')
#time.sleep(3.0 - ((time.time() - starttime) % 3.0))
#check(randm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-82d956ef8825> in <module>
#       5 #def check(classes):
#       6 #starttime=time.time()
# ----> 7 threading.Timer(2.0, check).start()
#       8 string = re.sub("[^a-zA-z]", " ", str(randm))
#       9 if 'Open' in string:
#
# NameError: name 'check' is not defined

# %% [markdown]
# import re
# string = re.sub("[^a-zA-z]", " ", str(html))
# if 'Class Full' not in string:
#
#     import smtplib
#     from email.mime.multipart import MIMEMultipart
#     from email.mime.text import MIMEText
#
#     me = "mb.motaz@gmail.com"
#     my_password = r"eviltower"
#     you = "motazb@g.ucla.edu"
#
#     msg = MIMEMultipart('alternative')
#     msg['Subject'] = "Class is Full"
#     msg['From'] = me
#     msg['To'] = you
#
#     html = '<html><body><p>Its still full!</p></body></html>'
#     part2 = MIMEText(html, 'html')
#
#     msg.attach(part2)
#
#     s = smtplib.SMTP_SSL('smtp.gmail.com')
#     s.login(me, my_password)
#
#     s.sendmail(me, you, msg.as_string())
#     s.quit()

# %%
from urllib.request import urlopen

html = urlopen("https://sa.ucla.edu/ro/Public/SOC/Results/ClassDetail?term_cd=20S&subj_area_cd=AF%20AMER&crs_catlg_no=0019%20%20%20%20&class_id=413057202&class_no=%20002%20%20").read()
print(html)
# Out:
# b'\r\n<!DOCTYPE html>\r\n<html lang="en">\r\n    <head>\r\n        <meta charset="utf-8" />\r\n        <base />\r\n            <title>Class Detail - Class Detail</title>\r\n        <link rel="shortcut icon" href="/ro/iwe/img/favicon.ico" type="image/x-icon" />\r\n        <meta name="viewport" content="width=device-width" />\r\n        <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">    \r\n        \r\n            <link rel="stylesheet" href="/ro/iwe/css/bundle/IweCssAll.css">\r\n        <link href="/ro/bundles/SOCCSS?v=u9WljaSkldTgZiYo5xJmEh6Scgr7fcUfLFhOmgL0SbQ1" rel="stylesheet"/>\r\n\r\n        \r\n    \r\n    <link href="/ro/bundles/SOCCSS?v=u9WljaSkldTgZiYo5xJmEh6Scgr7fcUfLFhOmgL0SbQ1" rel="stylesheet"/>\r\n\r\n\r\n    \r\n        <script src="/ro/bundles/iwejsAll?v=k6DtEPKLDcO_sYmZit4_jaBFA95O31KGhQJBp_TST7o1"></script>\r\n\r\n                \r\n\r\n        <meta id="MetaDescription" name="DESCRIPTION" content="UCLA Registrar\xe2\x80\x99s Office website offers in
# ...

# %%
import re
string = re.sub("[^a-zA-z]", " ", str(html))

import threading
def printit():
    threading.Timer(1.0, printit).start()
    if 'Open' in string:
        print('Open')
printit()
# Out:
# Open
# Open
# Open
# Open
# Open
# Open
# Open
# Open

# %%
string = "Open"

# %%
import time
starttime=time.time()

while 'Open' not in string:
    continue
else:
    print("Open")

time.sleep(3.0 - ((time.time() - starttime) % 3.0))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-147-8030d78dcdc0> in <module>
#       2 starttime=time.time()
#       3
# ----> 4 while 'Open' not in string:
#       5     continue
#       6 else:
#
# KeyboardInterrupt:
